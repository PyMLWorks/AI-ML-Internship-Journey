# %%
import numpy as np
arr=np.array([10,20,30,40])
arr
# Out:
# array([10, 20, 30, 40])

# %%
arr + 5
# Out:
# array([15, 25, 35, 45])

# %%
arr * 2
# Out:
# array([20, 40, 60, 80])

# %%
arr -10
# Out:
# array([ 0, 10, 20, 30])

# %%
arr/2
# Out:
# array([ 5., 10., 15., 20.])

# %%
arr.shape
# Out:
# (4,)

# %%
arr.dtype
# Out:
# dtype('int32')

# %%
marks=np.array([88,45,79,95,67])
marks
# Out:
# array([88, 45, 79, 95, 67])

# %%
marks > 50
# Out:
# array([ True, False,  True,  True,  True])
