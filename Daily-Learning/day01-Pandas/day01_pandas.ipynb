# %%
import pandas as pd

students={
    "Name": ["rahul", "priya","aryan","sam","sima","sham","ram","ana"],
    "Age":[22,None,23,20,None,19,20,20],
    "Marks":[88,45,None,35,50,90,None,78]
}
df=pd.DataFrame(students)
print(df)
# Out:
#     Name  Age  Marks
# 0  rahul   22     88
# 1  priya   21     45
# 2  aryan   23     79
# 3    sam   20     35
# 4   sima   25     50
# 5   sham   19     90
# 6    ram   20     67
# 7    ana   20     78

# %%
df.head()
# Out:
#     Name  Age  Marks
# 0  rahul   22     88
# 1  priya   21     45
# 2  aryan   23     79
# 3    sam   20     35
# 4   sima   25     50

# %%
df.shape
# Out:
# (8, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='object')
