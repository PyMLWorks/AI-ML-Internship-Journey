# %%
import pandas as pd

students={
    "Name": ["rahul", "priya","aryan","sam","sima","ram"],
    "Age":[22,23,20,19,20,20],
    "Marks":[88,45,35,50,90,78]
}
df=pd.DataFrame(students)

# %%
df.head()
# Out:
#     Name  Age  Marks
# 0  rahul   22     88
# 1  priya   23     45
# 2  aryan   20     35
# 3    sam   19     50
# 4   sima   20     90

# %%
df[df("Marks")<80]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df[df("Marks")>80]
#
# TypeError: 'DataFrame' object is not callable
